# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import numpy as np 

url = "https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv"
df = pd.read_csv(url)
iris = pd.read_csv(url)

print(iris.shape)
print(iris.head())
print(iris.columns)
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %% [markdown]
# ### what are the column we have

# %%
print(iris.columns)
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='str')

# %% [markdown]
# ### how many datapoints for each class are present ?
# # how many flowers are

# %%
iris["species"].value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %% [markdown]
# ### 2d scatter plot

# %%
iris.plot(kind = 'scatter', x = "sepal_length", y = "sepal_width")
plt.show()

# %% [markdown]
# ## 2d scatter plot with color

# %%
sns.axes_style("whitegrid")
sns.FacetGrid(iris , hue = "species", height = 4) \
.map(plt.scatter,"sepal_length","sepal_width") \
.add_legend()
plt.GridSpec
plt.show()

# %% [markdown]
# we can separate setposa  via linearly from other  versicolor and verginica

# %% [markdown]
# ## 3d scatter plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111,projection= '3d')

#plot for each species
for species in iris['species'].unique():
    subset =iris[iris['species']==species]

    ax.scatter(
        subset['sepal_length'],
        subset['sepal_width'],
        subset['petal_length'],
        label = species
    )
#labels
ax.set_xlabel("sepal Length")
ax.set_ylabel("sepal Width")
ax.set_zlabel("Petal Length")

ax.legend()
plt.show()

# %% [markdown]
# ## 4d plot

# %%
import sys
# !{sys.executable} -m pip install plotly
# Out:
# 'e:\datascience' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import nbformat
print(nbformat.__version__)
# Out:
# 5.10.4

# %%
import plotly.io as pio
pio.renderers.default = "browser"

# %%
import plotly.express as px

fig = px.scatter_3d(
    iris,
    x='sepal_length',
    y='sepal_width',
    z='petal_length',
    color='petal_width',   # 4th dimension
    size='petal_width',    # optional extra dimension
)

fig.show()

# %% [markdown]
# ### pairwise scatterplot
# 1. pairplot
# 2.disadvantage
# 3. can be used when numbers of featues are high
# 4. cannot visualize pattern in 3 or 4 d
# imensionals
#
# 5. how many plot we will get
# 4c2
# only possible to view two dimensionals

# %%
plt.close()
sns.set_style("ticks")
sns.pairplot(iris,hue ="species",size =3 )
plt.grid()
plt.show()
# Out:
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:2100: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# limitations

# %% [markdown]
# ### histogram, pdf
# 1d sctatter plot
#
# ##### what about 1d scatter plot just using one feature ?

# %%
iris_setosa = iris.loc[iris["species"] == "setosa"]
iris_virginica = iris.loc[iris["species"] == "virginica"]
iris_versicolor = iris.loc[iris["species"] == "versicolor"]

plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa['petal_length']))
plt.show()

# %%
## 1-d scatter plot of petal length
"""iris_setosa = iris.loc[iris["species"] == "setosa"]
iris_virginica = iris.loc[iris["species"] == "virginica"]
iris_versicolor = iris.loc[iris["species"] == "versicolor"]

plt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa['petal_length']))
plt.show()"""
# Out:
# 'iris_setosa = iris.loc[iris["species"] == "setosa"]\niris_virginica = iris.loc[iris["species"] == "virginica"]\niris_versicolor = iris.loc[iris["species"] == "versicolor"]\n\nplt.plot(iris_setosa["petal_length"],np.zeros_like(iris_setosa[\'petal_length\']))\nplt.show()'

# %%
import seaborn as sns
sns.FacetGrid(iris,hue ="species", height = 3)\
.map(sns.distplot,"petal_length")\
.add_legend()
plt.show()
# Out:
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ### the blue smoothline that is called pdf
# ### where we can see for setosa petal length cannot be >= 2
# ### we can say if a iris flower petal length is >= 5 that will be virginica because we have more options for where we can see virginica has petal length >=5

# %% [markdown]
# ## univariate analysis

# %%
sns.FacetGrid(iris,hue ="species",height= 3)\
.map(sns.distplot, "petal_width")\
.add_legend()
plt.show()
# Out:
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ### using sepal length

# %%
sns.FacetGrid(iris, hue= "species", height= 3)\
.map(sns.distplot,"sepal_length")\
.add_legend()
plt.show()
# Out:
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ### using sepal width

# %%
sns.FacetGrid(iris, hue = "species", height = 4 )\
.map(sns.distplot,"sepal_width")\
.add_legend()
plt.show
# Out:
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   func(*plot_args, **plot_kwargs)
# e:\datascience file\datascience\venv\Lib\site-packages\seaborn\axisgrid.py:854: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...
